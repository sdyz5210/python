# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_table(r"nipt-data.txt",sep='\t',index_col=0)
data.head()
# Out:
#             concentration  outlier_region_count  invalid_region_count  \
# sample
# T16TP26240         378.85                     0                     2
# T16TP26245         193.63                     0                     1
# T16TP26258         146.34                     1                     1
# T16TP26586          82.88                     0                     0
# T16TP3355           34.84                     0                     0
#
#             uniq_mapped_reads  uniq_mapped_ratio  uniq_GC_ratio  coverage  \
# sample
# T16TP26240           18686888           0.645232       0.397744  0.997032
# T16TP26245           15568421           0.639639       0.402218  0.999945
# T16TP26258           13508737           0.647621       0.405951  0.999972
# T16TP26586           13200816           0.597590       0.404526  0.996894
# T16TP3355            14685306           0.643772       0.402772  0.996867
#
#                  Q30                 qc
# sample
# ...

# %%
bins = []
labels = []
for i in range(0,540,20):
    bins.append(i)
    labels.append(str(i)+"_"+str(i+20))
df['fenzu'] = pd.cut(df['data'], bins=listBins, labels=listLabels, include_lowest=True)
# Out:
# [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520]
# ['0_20', '20_40', '40_60', '60_80', '80_100', '100_120', '120_140', '140_160', '160_180', '180_200', '200_220', '220_240', '240_260', '260_280', '280_300', '300_320', '320_340', '340_360', '360_380', '380_400', '400_420', '420_440', '440_460', '460_480', '480_500', '500_520', '520_540']

# %%
# Out:
# No handles with labels found to put in legend.
